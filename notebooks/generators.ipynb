# %%
#To help us import from outside folder
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))
import matplotlib.pyplot as plt
import pandas as pd
from generatorReadMidi import GeneratorReadMidi
import os
import sys
import pandas as pd
from generatorReadMidi import GeneratorReadMidi

current_dir = os.getcwd()

plt.figure(figsize=(10, 10))

# Set the number of sequences to plot
num_sequences_to_plot = 1

midi_file_path = "../data/midi/test.mid"

# Create an instance of the GeneratorReadMidi class
generator = GeneratorReadMidi()

# Read the MIDI file normally
data = generator.readMidi(midi_file_path)
print(data)

# Read the MIDI file using the generator 
data = generator.readMidiGenerator(midi_file_path)

for d in data:
    print(d)
# Out:
# [MetaMessage('smpte_offset', frame_rate=30, hours=0, minutes=0, seconds=0, frames=0, sub_frames=0, time=0), MetaMessage('time_signature', numerator=3, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0), MetaMessage('key_signature', key='Bb', time=0), MetaMessage('set_tempo', tempo=499999, time=0), MetaMessage('set_tempo', tempo=666669, time=0), MetaMessage('set_tempo', tempo=666669, time=0), MetaMessage('device_name', name='SmartMusic SoftSynth 1', time=0), MetaMessage('track_name', name='Piano', time=0), Message('program_change', channel=0, program=1, time=0), Message('control_change', channel=0, control=7, value=101, time=0), Message('control_change', channel=0, control=10, value=64, time=0), Message('control_change', channel=0, control=7, value=102, time=0), Message('control_change', channel=0, control=7, value=110, time=0), Message('control_change', channel=0, control=100, value=0, time=0.0019531318359375), Message('control_change', channel=0, control=101, value=0, time=0), Message('control_change', channel=0, control=100, value=0, time=0), Message('control_change', channel=0, control=101, value=0, time=0), Message('control_change', channel=0, control=6, value=12, time=0.0006510439453125), Message('control_change', channel=0, control=6, value=12, time=0), Message('control_change', channel=0, control=38, value=0, time=0.0006510439453125), Message('control_change', channel=0, control=38, value=0, time=0), Message('control_change', channel=0, control=7, value=102, time=0.0032552197265624996), Message('note_on', channel=0, note=46, velocity=50, time=0), Message('note_on', channel=0, note=53, velocity=50, time=0.347657466796875), Message('note_off', channel=0, note=46, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=58, velocity=50, time=0.29036559960937497), Message('note_off', channel=0, note=53, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=62, velocity=50, time=0.2923187314453125), Message('note_off', channel=0, note=58, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=58, velocity=50, time=0.2910166435546875), Message('note_off', channel=0, note=62, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=53, velocity=45, time=0.28711037988281246), Message('note_off', channel=0, note=58, velocity=0, time=0.039062636718749995), Message('note_off', channel=0, note=53, velocity=0, time=0.287761423828125), Message('note_on', channel=0, note=43, velocity=50, time=0.0045573076171875), Message('note_on', channel=0, note=50, velocity=50, time=0.35156373046875), Message('note_off', channel=0, note=43, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=55, velocity=50, time=0.29036559960937497), Message('note_off', channel=0, note=50, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=58, velocity=50, time=0.2923187314453125), Message('note_off', channel=0, note=55, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=55, velocity=50, time=0.2910166435546875), Message('note_off', channel=0, note=58, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=50, velocity=45, time=0.28711037988281246), Message('note_off', channel=0, note=55, velocity=0, time=0.039062636718749995), Message('note_off', channel=0, note=50, velocity=0, time=0.287761423828125), Message('note_on', channel=0, note=48, velocity=50, time=0.0045573076171875), Message('note_on', channel=0, note=55, velocity=50, time=0.35156373046875), Message('note_off', channel=0, note=48, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=58, velocity=50, time=0.29036559960937497), Message('note_off', channel=0, note=55, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, note=65, velocity=50, time=0.2923187314453125), Message('note_off', channel=0, note=58, velocity=0, time=0.039062636718749995), Message('note_on', channel=0, no ...
# MetaMessage('smpte_offset', frame_rate=30, hours=0, minutes=0, seconds=0, frames=0, sub_frames=0, time=0)
# MetaMessage('time_signature', numerator=3, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0)
# MetaMessage('key_signature', key='Bb', time=0)
